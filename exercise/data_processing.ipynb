# %%
import pandas as pd
data = {"city" : ["Göteborg", "Stockholm", "Uppsala", "Malmö" ],
    "population" : [583056, 975551, 233839, 583056]}

cities_df = pd.DataFrame(data)

# %%
cities_df[cities_df['city'] == 'Göteborg']
# Out:
#        city  population
# 0  Göteborg      583056

# %%
sortedcity = cities_df.sort_values("population", ascending=False)
sortedcity
# Out:
#         city  population
# 1  Stockholm      975551
# 0   Göteborg      583056
# 3      Malmö      583056
# 2    Uppsala      233839

# %%
top_3_cities = sortedcity.head(3)
top_3_cities
# Out:
#         city  population
# 1  Stockholm      975551
# 0   Göteborg      583056
# 3      Malmö      583056

# %%
sweden_population_2020 = 10379295
sortedcity["Population (%)"] = (sortedcity["population"] / sweden_population_2020) * 100
print(sortedcity)
# Out:
#         city  population  Population (%)
# 1  Stockholm      975551        9.399010
# 0   Göteborg      583056        5.617491
# 3      Malmö      583056        5.617491
# 2    Uppsala      233839        2.252937

# %%
df_topp50 = pd.read_excel("../data/data_processing/komtopp50_2020.xlsx", sheet_name="Totalt")

df_topp50= df_topp50.iloc[6:]
df_topp50
# Out:
#     Unnamed: 0  Unnamed: 1    Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5
# 6           83        84.0           Ale      31868     31402.0   1.483982
# 7           64        64.0      Alingsås      41602     41420.0   0.439401
# 8          123       123.0       Alvesta      20224     20134.0   0.447005
# 9          255       255.0         Aneby       6821      6848.0  -0.394276
# 10         169       167.0        Arboga      14039     14087.0   -0.34074
# ..         ...         ...           ...        ...         ...        ...
# 291         54        55.0     Österåker      46644     45574.0    2.34783
# 292        116       115.0     Östhammar      22251     22250.0   0.004494
# 293        160       159.0  Östra Göinge      15017     15007.0   0.066636
# 294        284       284.0     Överkalix       3289      3315.0  -0.784314
# 295        279       279.0    Övertorneå       4217      4299.0   -1.90742
#
# [290 rows x 6 columns]

# %%
column_names = {
    "Unnamed: 0": "Rang 2020",
    "Unnamed: 1": "Rang 2019",
    "Unnamed: 2": "Kommun",
    "Unnamed: 3": "Folkmängd 2020",
    "Unnamed: 4": "Folkmängd 2019",
    "Unnamed: 5": "Förändring %"
}
df_topp50.rename(columns=column_names, inplace=True)
df_topp50
# Out:
#     Rang 2020  Rang 2019        Kommun Folkmängd 2020  Folkmängd 2019  \
# 6          83       84.0           Ale          31868         31402.0
# 7          64       64.0      Alingsås          41602         41420.0
# 8         123      123.0       Alvesta          20224         20134.0
# 9         255      255.0         Aneby           6821          6848.0
# 10        169      167.0        Arboga          14039         14087.0
# ..        ...        ...           ...            ...             ...
# 291        54       55.0     Österåker          46644         45574.0
# 292       116      115.0     Östhammar          22251         22250.0
# 293       160      159.0  Östra Göinge          15017         15007.0
# 294       284      284.0     Överkalix           3289          3315.0
# 295       279      279.0    Övertorneå           4217          4299.0
#
#     Förändring %
# 6       1.483982
# 7       0.439401
# 8       0.447005
# 9      -0.394276
# 10      -0.34074
# ...

# %%
sortedcitys = df_topp50.sort_values(by=("Folkmängd 2020"), ascending=False)
sortedcitys
# Out:
#     Rang 2020  Rang 2019     Kommun Folkmängd 2020  Folkmängd 2019  \
# 204         1        1.0  Stockholm         975551        974073.0
# 63          2        2.0   Göteborg         583056        579281.0
# 140         3        3.0      Malmö         347949        344166.0
# 247         4        4.0    Uppsala         233839        230767.0
# 130         5        5.0  Linköping         164616        163051.0
# ..        ...        ...        ...            ...             ...
# 277       286      286.0      Åsele           2805          2794.0
# 11        287      287.0   Arjeplog           2718          2785.0
# 35        288      288.0    Dorotea           2498          2551.0
# 200       289      289.0    Sorsele           2442          2489.0
# 18        290      290.0   Bjurholm           2387          2408.0
#
#     Förändring %
# 204     0.151734
# 63       0.65167
# 140     1.099179
# 247     1.331213
# 130     0.959822
# ..           ...
# 277     0.393701
# ...

# %%
lowestcitys = df_topp50.sort_values(by=("Folkmängd 2020"), ascending=True)
trimmed_df = lowestcitys.iloc[5:]
trimmed_df
# Out:
#     Rang 2020  Rang 2019     Kommun Folkmängd 2020  Folkmängd 2019  \
# 142       285      285.0       Malå           3024          3068.0
# 294       284      284.0  Överkalix           3289          3315.0
# 152       283      283.0   Munkfors           3725          3740.0
# 271       282      282.0       Ydre           3726          3747.0
# 163       281      281.0     Norsjö           3945          3986.0
# ..        ...        ...        ...            ...             ...
# 130         5        5.0  Linköping         164616        163051.0
# 247         4        4.0    Uppsala         233839        230767.0
# 140         3        3.0      Malmö         347949        344166.0
# 63          2        2.0   Göteborg         583056        579281.0
# 204         1        1.0  Stockholm         975551        974073.0
#
#     Förändring %
# 142    -1.434159
# 294    -0.784314
# 152     -0.40107
# 271    -0.560448
# 163      -1.0286
# ..           ...
# 130     0.959822
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/data_processing/student-mat-missing-data.csv")
df
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 0             0     GP   F  18.0       U     GT3       A     4     4
# 1             1     GP   F  17.0       U     GT3       T     1     1
# 2             2     GP   F  15.0       U     LE3       T     1     1
# 3             3     GP   F  15.0       U     GT3       T     4     2
# 4             4     GP   F  16.0       U     GT3       T     3     3
# ..          ...    ...  ..   ...     ...     ...     ...   ...   ...
# 390         390     MS   M  20.0       U     LE3       A     2     2
# 391         391     MS   M  17.0       U     LE3       T     3     1
# 392         392     MS   M  21.0       R     GT3       T     1     1
# 393         393     MS   M  18.0       R     LE3       T     3     2
# 394         394     MS   M  19.0       U     LE3       T     1     1
#
#          Mjob  ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  \
# ...

# %%
from data_utils import plot_missing_values
plot_missing_values(df)

# %%
rows_with_nan_freetime = df[df['freetime'].isna() | df['age'].isna()]

# Print or further process the rows
print(rows_with_nan_freetime.head(33))
# Out:
#      Unnamed: 0 school sex   age address famsize Pstatus  Medu  Fedu  \
# 20           20     GP   M   NaN       U     GT3       T     4     3
# 71           71     GP   M   NaN       U     GT3       T     4     2
# 87           87     GP   F  15.0       U     GT3       T     4     2
# 99           99     GP   F  16.0       U     GT3       T     4     3
# 102         102     GP   M   NaN       U     GT3       T     4     4
# 106         106     GP   F   NaN       U     GT3       T     2     2
# 121         121     GP   M   NaN       U     GT3       T     2     2
# 130         130     GP   F  15.0       R     GT3       T     3     4
# 149         149     GP   M  15.0       U     LE3       A     2     1
# 151         151     GP   M  16.0       U     LE3       T     2     1
# 160         160     GP   M   NaN     NaN     LE3       T     2     1
# 188         188     GP   F   NaN       U     GT3       A     3     3
# 191         191     GP   F   NaN     NaN     GT3       T     1     1
# ...

# %%
rows_with_multiple_nans = df[df.isnull().sum(axis=1) > 1]

# Compute the proportion
proportion_of_rows_with_multiple_nans = len(rows_with_multiple_nans) / len(df) * 100

# Print the proportion
print("Proportion of rows with multiple NaNs:", proportion_of_rows_with_multiple_nans, "%")
# Out:
# Proportion of rows with multiple NaNs: 1.2658227848101267 %
